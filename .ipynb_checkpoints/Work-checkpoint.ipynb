# %%
# !pip install gymnasium
# !pip install pyglet
# !pip install pygame
# Out:
# Requirement already satisfied: gymnasium in c:\users\leigh\anaconda3\lib\site-packages (0.29.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (4.8.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\leigh\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.6.0)
# Requirement already satisfied: pyglet in c:\users\leigh\anaconda3\lib\site-packages (2.0.9)
# Requirement already satisfied: pygame in c:\users\leigh\anaconda3\lib\site-packages (2.5.1)

# %%
#This is the mannual game play cell
import gymnasium as gym
from gym.envs.classic_control.cartpole import *
from pyglet.window import key
import matplotlib.pyplot as plt
import time
from gymnasium.utils.play import play

bool_do_not_quit = True  # Boolean to quit pyglet
scores = []  # Your gaming score
a = 0  # Action
total_reward = 0
episode = 1
steps = 0
start_time = time.time()

def cartpole_callback(obs, q_obs, action, reward, terminated, truncated, info):
    global total_reward, steps, start_time
    total_reward += reward
    steps += 1
    if terminated or truncated:
        print("Episode", len(scores), "| Score:", total_reward, '|', steps, "steps | %0.2fs."% (time.time()-start_time))
        scores.append(total_reward)
        total_reward = 0
        steps = 0
        start_time = time.time()
    
    
    
def run_cartPole_asHuman(policy=None):
    env = gym.make('CartPole-v1', render_mode="rgb_array")
    env.reset()
    play(env, keys_to_action={"a":0, "d":1}, callback=cartpole_callback, fps=10)



run_cartPole_asHuman() 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import statistics
print("Average Score for ", len(scores), " episodes is:",statistics.mean(scores))
# Plot your score
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.title('My human performance on CartPole-v1')
plt.ylabel('Score')
plt.xlabel('Human Episode')
plt.show()
# Out:
# Episode 0 | Score: 9.0 | 9 steps | 0.91s.
# Episode 1 | Score: 8.0 | 8 steps | 1.82s.
# Episode 2 | Score: 9.0 | 9 steps | 2.82s.
# Episode 3 | Score: 10.0 | 10 steps | 3.93s.
# Episode 4 | Score: 8.0 | 8 steps | 4.83s.
# Episode 5 | Score: 9.0 | 9 steps | 5.83s.
# Episode 6 | Score: 8.0 | 8 steps | 6.74s.
# Episode 7 | Score: 10.0 | 10 steps | 7.84s.
# Episode 8 | Score: 9.0 | 9 steps | 8.85s.
# Episode 9 | Score: 9.0 | 9 steps | 9.85s.
# Episode 10 | Score: 10.0 | 10 steps | 10.96s.
# Episode 11 | Score: 9.0 | 9 steps | 11.96s.
# Episode 12 | Score: 10.0 | 10 steps | 13.07s.
# Episode 13 | Score: 9.0 | 9 steps | 14.07s.
# Episode 14 | Score: 10.0 | 10 steps | 15.18s.
# Episode 15 | Score: 8.0 | 8 steps | 16.08s.
# Episode 16 | Score: 9.0 | 9 steps | 17.09s.
# Episode 17 | Score: 10.0 | 10 steps | 18.20s.
# Episode 18 | Score: 10.0 | 10 steps | 19.30s.
# Episode 19 | Score: 9.0 | 9 steps | 20.31s.
# Episode 20 | Score: 10.0 | 10 steps | 21.42s.
# Episode 21 | Score: 9.0 | 9 steps | 22.43s.
# Episode 22 | Score: 10.0 | 10 steps | 23.53s.
# Episode 23 | Score: 8.0 | 8 steps | 24.44s.
# Episode 24 | Score: 9.0 | 9 steps | 25.44s.
# Episode 25 | Score: 9.0 | 9 steps | 26.45s.
# Episode 26 | Score: 10.0 | 10 steps | 27.55s.
# Episode 27 | Score: 9.0 | 9 steps | 28.55s.
# Episode 28 | Score: 9.0 | 9 steps | 29.56s.
# Episode 29 | Score: 10.0 | 10 steps | 30.67s.
# Episode 30 | Score: 9.0 | 9 steps | 31.67s.
# Episode 31 | Score: 10.0 | 10 steps | 32.78s.
# Episode 32 | Score: 9.0 | 9 steps | 33.78s.
# Episode 33 | Score: 10.0 | 10 steps | 34.89s.
# Episode 34 | Score: 10.0 | 10 steps | 35.99s.
# Episode 35 | Score: 9.0 | 9 steps | 37.00s.
# Episode 36 | Score: 10.0 | 10 steps | 38.11s.
# Episode 37 | Score: 9.0 | 9 steps | 39.12s.
# Episode 38 | Score: 9.0 | 9 steps | 40.12s.
# Episode 39 | Score: 10.0 | 10 steps | 41.23s.
# Episode 40 | Score: 10.0 | 10 steps | 42.33s.
# Episode 41 | Score: 10.0 | 10 steps | 43.44s.
# Episode 42 | Score: 10.0 | 10 steps | 44.55s.
# Episode 43 | Score: 8.0 | 8 steps | 45.45s.
# Episode 44 | Score: 10.0 | 10 steps | 46.56s.
# Episode 45 | Score: 10.0 | 10 steps | 47.67s.
# Episode 46 | Score: 9.0 | 9 steps | 48.67s.
# Episode 47 | Score: 9.0 | 9 steps | 49.68s.
# Episode 48 | Score: 9.0 | 9 steps | 50.68s.
# Episode 49 | Score: 8.0 | 8 steps | 51.59s.
# Episode 50 | Score: 10.0 | 10 steps | 52.69s.
# Episode 51 | Score: 9.0 | 9 steps | 53.70s.
# Episode 52 | Score: 9.0 | 9 steps | 54.71s.
# Episode 53 | Score: 10.0 | 10 steps | 55.81s.
# Episode 54 | Score: 11.0 | 11 steps | 57.01s.
# Episode 55 | Score: 10.0 | 10 steps | 58.12s.
# Episode 56 | Score: 10.0 | 10 steps | 59.23s.
# Episode 57 | Score: 8.0 | 8 steps | 60.13s.
# Episode 58 | Score: 9.0 | 9 steps | 61.14s.
# Episode 59 | Score: 10.0 | 10 steps | 62.25s.
# Episode 60 | Score: 10.0 | 10 steps | 63.35s.
# Episode 61 | Score: 10.0 | 10 steps | 64.45s.
# Episode 62 | Score: 10.0 | 10 steps | 65.56s.
# Episode 63 | Score: 9.0 | 9 steps | 66.57s.
# Episode 64 | Score: 10.0 | 10 steps | 67.67s.
# Episode 65 | Score: 9.0 | 9 steps | 68.67s.
# Episode 66 | Score: 10.0 | 10 steps | 69.78s.
# Episode 67 | Score: 8.0 | 8 steps | 70.68s.
# Episode 68 | Score: 9.0 | 9 steps | 71.69s.
# Episode 69 | Score: 10.0 | 10 steps | 72.80s.
# Episode 70 | Score: 9.0 | 9 steps | 73.81s.
# Episode 71 | Score: 10.0 | 10 steps | 74.91s.
# Episode 72 | Score: 10.0 | 10 steps | 76.02s.
# Episode 73 | Score: 9.0 | 9 steps | 77.02s.
# Episode 74 | Score: 9.0 | 9 steps | 78.02s.
# Episode 75 | Score: 10.0 | 10 steps | 79.13s.
# Episode 76 | Score: 8.0 | 8 steps | 80.04s.
# Episode 77 | Score: 10.0 | 10 steps | 81.14s.
# Episode 78 | Score: 9.0 | 9 steps | 82.15s.
# Episode 79 | Score: 9.0 | 9 steps | 83.15s.
# Episode 80 | Score: 8.0 | 8 steps | 84.06s.
# Episode 81 | Score: 8.0 | 8 steps | 84.96s.
# Episode 82 | Score: 8.0 | 8 steps | 85.87s.
# Episode 83 | Score: 8.0 | 8 steps | 86.77s.
# Episode 84 | Score: 10.0 | 10 steps | 87.88s.
# Episode 85 | Score: 11.0 | 11 steps | 89.08s.
# Episode 86 | Score: 9.0 | 9 steps | 90.09s.
# Episode 87 | Score: 10.0 | 10 steps | 91.20s.
# Episode 88 | Score: 10.0 | 10 steps | 92.30s.
# Episode 89 | Score: 10.0 | 10 steps | 93.41s.
# Episode 90 | Score: 9.0 | 9 steps | 94.42s.
# Episode 91 | Score: 10.0 | 10 steps | 95.52s.
# Episode 92 | Score: 8.0 | 8 steps | 96.43s.
# Episode 93 | Score: 10.0 | 10 steps | 97.53s.
# Episode 94 | Score: 10.0 | 10 steps | 98.64s.
# Episode 95 | Score: 9.0 | 9 steps | 99.64s.
# Episode 96 | Score: 10.0 | 10 steps | 100.75s.
# Episode 97 | Score: 10.0 | 10 steps | 101.85s.
# Episode 98 | Score: 9.0 | 9 steps | 102.86s.
# Episode 99 | Score: 8.0 | 8 steps | 103.76s.
# Episode 100 | Score: 9.0 | 9 steps | 104.77s.
# Episode 101 | Score: 10.0 | 10 steps | 105.87s.
# Episode 102 | Score: 10.0 | 10 steps | 106.98s.
# Episode 103 | Score: 9.0 | 9 steps | 107.99s.
# Episode 104 | Score: 9.0 | 9 steps | 108.99s.
# Episode 105 | Score: 9.0 | 9 steps | 110.00s.
# Episode 106 | Score: 9.0 | 9 steps | 111.00s.
# Episode 107 | Score: 9.0 | 9 steps | 112.01s.
# Episode 108 | Score: 10.0 | 10 steps | 113.12s.
# Episode 109 | Score: 10.0 | 10 steps | 114.22s.
# Episode 110 | Score: 9.0 | 9 steps | 115.23s.
# Episode 111 | Score: 11.0 | 11 steps | 116.43s.
# Episode 112 | Score: 8.0 | 8 steps | 117.34s.
# Episode 113 | Score: 9.0 | 9 steps | 118.34s.
# Episode 114 | Score: 10.0 | 10 steps | 119.45s.
# Episode 115 | Score: 9.0 | 9 steps | 120.45s.
# Episode 116 | Score: 9.0 | 9 steps | 121.46s.
# Episode 117 | Score: 9.0 | 9 steps | 122.46s.
# Episode 118 | Score: 9.0 | 9 steps | 123.47s.
# Episode 119 | Score: 10.0 | 10 steps | 124.58s.
# Episode 120 | Score: 8.0 | 8 steps | 125.48s.
# Episode 121 | Score: 10.0 | 10 steps | 126.59s.
# Episode 122 | Score: 8.0 | 8 steps | 127.49s.
# Episode 123 | Score: 10.0 | 10 steps | 128.60s.
# Episode 124 | Score: 8.0 | 8 steps | 129.51s.
# Episode 125 | Score: 8.0 | 8 steps | 130.41s.
# Episode 126 | Score: 8.0 | 8 steps | 131.32s.
# Episode 127 | Score: 9.0 | 9 steps | 132.32s.
# Episode 128 | Score: 9.0 | 9 steps | 133.33s.
# Episode 129 | Score: 9.0 | 9 steps | 134.33s.
# Episode 130 | Score: 9.0 | 9 steps | 135.34s.
# Episode 131 | Score: 9.0 | 9 steps | 136.34s.
# Episode 132 | Score: 9.0 | 9 steps | 137.35s.
# Episode 133 | Score: 8.0 | 8 steps | 138.25s.
# Episode 134 | Score: 10.0 | 10 steps | 139.35s.
# Episode 135 | Score: 9.0 | 9 steps | 140.36s.
# Episode 136 | Score: 10.0 | 10 steps | 141.46s.
# Episode 137 | Score: 9.0 | 9 steps | 142.47s.
# Episode 138 | Score: 10.0 | 10 steps | 143.58s.
# Episode 139 | Score: 10.0 | 10 steps | 144.68s.
# Episode 140 | Score: 10.0 | 10 steps | 145.78s.
# Episode 141 | Score: 10.0 | 10 steps | 146.89s.
# Episode 142 | Score: 9.0 | 9 steps | 147.89s.
# Episode 143 | Score: 10.0 | 10 steps | 148.99s.
# Episode 144 | Score: 10.0 | 10 steps | 150.10s.
# Episode 145 | Score: 10.0 | 10 steps | 151.21s.
# Episode 146 | Score: 10.0 | 10 steps | 152.31s.
# Episode 147 | Score: 10.0 | 10 steps | 153.42s.
# Episode 148 | Score: 10.0 | 10 steps | 154.52s.
# Episode 149 | Score: 10.0 | 10 steps | 155.63s.
# Episode 150 | Score: 8.0 | 8 steps | 156.53s.
# Episode 151 | Score: 10.0 | 10 steps | 157.64s.
# Episode 152 | Score: 10.0 | 10 steps | 158.75s.
# Episode 153 | Score: 9.0 | 9 steps | 159.75s.
# Episode 154 | Score: 9.0 | 9 steps | 160.76s.
# Episode 155 | Score: 11.0 | 11 steps | 161.97s.
# Episode 156 | Score: 9.0 | 9 steps | 162.97s.
# Episode 157 | Score: 8.0 | 8 steps | 163.88s.
# Episode 158 | Score: 10.0 | 10 steps | 164.99s.
# Episode 159 | Score: 10.0 | 10 steps | 166.09s.
# Episode 160 | Score: 9.0 | 9 steps | 167.10s.
# Episode 161 | Score: 9.0 | 9 steps | 168.10s.
# Episode 162 | Score: 10.0 | 10 steps | 169.21s.
# Episode 163 | Score: 8.0 | 8 steps | 170.11s.
# Episode 164 | Score: 9.0 | 9 steps | 171.12s.
# Episode 165 | Score: 9.0 | 9 steps | 172.13s.
# Episode 166 | Score: 8.0 | 8 steps | 173.03s.
# Episode 167 | Score: 10.0 | 10 steps | 174.13s.
# Episode 168 | Score: 9.0 | 9 steps | 175.14s.
# Episode 169 | Score: 11.0 | 11 steps | 176.35s.
# Episode 170 | Score: 10.0 | 10 steps | 177.45s.
# Episode 171 | Score: 8.0 | 8 steps | 178.36s.
# Episode 172 | Score: 8.0 | 8 steps | 179.26s.
# Episode 173 | Score: 10.0 | 10 steps | 180.37s.
# Episode 174 | Score: 10.0 | 10 steps | 181.48s.
# Episode 175 | Score: 10.0 | 10 steps | 182.58s.
# Episode 176 | Score: 9.0 | 9 steps | 183.58s.
# Episode 177 | Score: 9.0 | 9 steps | 184.59s.
# Episode 178 | Score: 10.0 | 10 steps | 185.69s.
# Episode 179 | Score: 10.0 | 10 steps | 186.80s.
# Episode 180 | Score: 9.0 | 9 steps | 187.80s.
# Episode 181 | Score: 9.0 | 9 steps | 188.81s.
# Episode 182 | Score: 9.0 | 9 steps | 189.82s.
# Episode 183 | Score: 9.0 | 9 steps | 190.82s.
# Episode 184 | Score: 9.0 | 9 steps | 191.83s.
# Episode 185 | Score: 10.0 | 10 steps | 192.94s.
# Episode 186 | Score: 8.0 | 8 steps | 193.84s.
# Episode 187 | Score: 9.0 | 9 steps | 194.85s.
# Episode 188 | Score: 8.0 | 8 steps | 195.75s.
# Episode 189 | Score: 10.0 | 10 steps | 196.86s.
# Episode 190 | Score: 10.0 | 10 steps | 197.96s.
# Episode 191 | Score: 10.0 | 10 steps | 199.07s.
# Episode 192 | Score: 11.0 | 11 steps | 200.27s.
# Episode 193 | Score: 10.0 | 10 steps | 201.38s.
# Episode 194 | Score: 10.0 | 10 steps | 202.48s.
# Episode 195 | Score: 10.0 | 10 steps | 203.59s.
# Episode 196 | Score: 10.0 | 10 steps | 204.70s.
# Episode 197 | Score: 8.0 | 8 steps | 205.60s.
# Episode 198 | Score: 10.0 | 10 steps | 206.71s.
# Episode 199 | Score: 9.0 | 9 steps | 207.71s.
# Episode 200 | Score: 8.0 | 8 steps | 208.61s.
# Episode 201 | Score: 10.0 | 10 steps | 209.72s.
# Episode 202 | Score: 10.0 | 10 steps | 210.82s.
# Episode 203 | Score: 9.0 | 9 steps | 211.83s.
# Episode 204 | Score: 10.0 | 10 steps | 212.94s.
# Episode 205 | Score: 9.0 | 9 steps | 213.94s.
# Episode 206 | Score: 9.0 | 9 steps | 214.95s.
# Episode 207 | Score: 9.0 | 9 steps | 215.95s.
# Episode 208 | Score: 8.0 | 8 steps | 216.86s.
# Episode 209 | Score: 8.0 | 8 steps | 217.76s.
# Episode 210 | Score: 10.0 | 10 steps | 218.87s.
# Episode 211 | Score: 9.0 | 9 steps | 219.87s.
# Episode 212 | Score: 9.0 | 9 steps | 220.88s.
# Episode 213 | Score: 9.0 | 9 steps | 221.89s.
# Episode 214 | Score: 9.0 | 9 steps | 222.89s.
# Episode 215 | Score: 10.0 | 10 steps | 224.00s.
# Episode 216 | Score: 10.0 | 10 steps | 225.10s.
# Episode 217 | Score: 9.0 | 9 steps | 226.11s.
# Episode 218 | Score: 8.0 | 8 steps | 227.01s.
# Episode 219 | Score: 10.0 | 10 steps | 228.12s.
# Episode 220 | Score: 10.0 | 10 steps | 229.23s.
# Episode 221 | Score: 9.0 | 9 steps | 230.23s.
# Episode 222 | Score: 9.0 | 9 steps | 231.24s.
# Episode 223 | Score: 8.0 | 8 steps | 232.14s.
# Episode 224 | Score: 10.0 | 10 steps | 233.24s.
# Episode 225 | Score: 9.0 | 9 steps | 234.25s.
# Episode 226 | Score: 10.0 | 10 steps | 235.36s.
# Episode 227 | Score: 9.0 | 9 steps | 236.36s.
# Episode 228 | Score: 9.0 | 9 steps | 237.37s.
# Episode 229 | Score: 10.0 | 10 steps | 238.48s.
# Episode 230 | Score: 8.0 | 8 steps | 239.38s.
# Episode 231 | Score: 10.0 | 10 steps | 240.49s.
# Episode 232 | Score: 9.0 | 9 steps | 241.49s.
# Episode 233 | Score: 10.0 | 10 steps | 242.60s.
# Episode 234 | Score: 10.0 | 10 steps | 243.70s.
# Episode 235 | Score: 9.0 | 9 steps | 244.71s.
# Episode 236 | Score: 9.0 | 9 steps | 245.71s.
# Episode 237 | Score: 11.0 | 11 steps | 246.92s.
# Episode 238 | Score: 9.0 | 9 steps | 247.92s.
# Episode 239 | Score: 11.0 | 11 steps | 249.13s.
# Episode 240 | Score: 10.0 | 10 steps | 250.23s.
# Episode 241 | Score: 9.0 | 9 steps | 251.24s.
# Episode 242 | Score: 9.0 | 9 steps | 252.24s.
# Episode 243 | Score: 9.0 | 9 steps | 253.25s.
# Episode 244 | Score: 10.0 | 10 steps | 254.35s.
# Episode 245 | Score: 8.0 | 8 steps | 255.26s.
# Episode 246 | Score: 8.0 | 8 steps | 256.16s.
# Episode 247 | Score: 9.0 | 9 steps | 257.17s.
# Episode 248 | Score: 8.0 | 8 steps | 258.08s.
# Episode 249 | Score: 9.0 | 9 steps | 259.08s.
# Episode 250 | Score: 10.0 | 10 steps | 260.19s.
# Episode 251 | Score: 10.0 | 10 steps | 261.29s.
# Episode 252 | Score: 8.0 | 8 steps | 262.20s.
# Episode 253 | Score: 10.0 | 10 steps | 263.31s.
# Episode 254 | Score: 9.0 | 9 steps | 264.31s.
# Episode 255 | Score: 10.0 | 10 steps | 265.42s.
# Episode 256 | Score: 10.0 | 10 steps | 266.52s.
# Episode 257 | Score: 9.0 | 9 steps | 267.53s.
# Episode 258 | Score: 10.0 | 10 steps | 268.63s.
# Episode 259 | Score: 10.0 | 10 steps | 269.74s.
# Episode 260 | Score: 9.0 | 9 steps | 270.74s.
# Episode 261 | Score: 8.0 | 8 steps | 271.65s.
# Episode 262 | Score: 9.0 | 9 steps | 272.65s.
# Episode 263 | Score: 9.0 | 9 steps | 273.65s.
# Episode 264 | Score: 10.0 | 10 steps | 274.76s.
# Episode 265 | Score: 9.0 | 9 steps | 275.76s.
# Episode 266 | Score: 10.0 | 10 steps | 276.87s.
# Episode 267 | Score: 10.0 | 10 steps | 277.97s.
# Episode 268 | Score: 9.0 | 9 steps | 278.97s.
# Episode 269 | Score: 10.0 | 10 steps | 280.08s.
# Average Score for  270  episodes is: 9.322222222222223

# %%
import gym
from gym.envs.classic_control.cartpole import *
from pyglet.window import key
import matplotlib.pyplot as plt
import time


bool_do_not_quit = True  # Boolean to quit pyglet
scores = []  # Your gaming score
a = 0  # Action
env = CartPoleEnv()

number_of_trials = 5000

def key_press(k, mod):
    global bool_do_not_quit, a, restart
    if k==0xff0d: restart = True
    if k==key.ESCAPE: bool_do_not_quit=False  # Added to Quit
    if k==key.Q: bool_do_not_quit=False  # Added to Quit
    if k==key.LEFT:  a = 0  # 0     Push cart to the left
    if k==key.RIGHT: a = 1  # 1     Push cart to the right

def dummy_policy(state=0):
    a = env.action_space.sample()
    return a



import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,BatchNormalization,Activation
from tensorflow.keras.callbacks import ModelCheckpoint
import datetime,os
import collections
import random
import copy

def build_model():
    inputs = keras.Input(shape=(4,))
    x = layers.Dense(32,activation='tanh')(inputs)
    x = layers.Dense(64,activation='tanh')(x)

    outputs = layers.Dense(2, activation="linear")(x)

    model = keras.Model(inputs=inputs, outputs=outputs, name="dqn_model")
    #lr stands for learning rate
    optimizer = keras.optimizers.Adam(lr=0.001)

    model.compile(
        optimizer =optimizer,loss='mse',
    )
    return model

model= build_model()
target_network = build_model()
gamma = 0.95

epsilon = 1.0/number_of_trials

episode_reward_list = []     
exploring_rate=0.0
target_score = 200

memory = collections.deque(maxlen=100000)
batch_size=32
max_reward = -10000
target_update_steps = 20


steps_to_target = 20
done=False

last_state = []
a = []
reward = 0
total_reward = 0.0



#Get the predictd best action by our network
def deep_q_policy(state):
            
    # Get the model's reward estimations of each Q(s,a)
    action_q_values = model.predict([[state[0],state[1],state[2],state[3]]])
    
    # If exploiting, choose the model's estimated best action 
    return np.argmax(action_q_values)



#Change our exploring rate so that later rounds are less random later on (because our network will hopefully be improving)
def update_exploring_rate(roundNumber):
    global exploring_rate
    exploring_rate = 1-roundNumber*epsilon 
    if exploring_rate<0:
        exploring_rate = 0.01


        
# Feed our network the batch of state changes and rewards
def experience_replay():
    global memory
    state_batch, q_batch = [], []
    # Get a batch of random state changes from memory to train our network
    minibatch = random.sample(memory, min(len(memory), batch_size))
    for m_state, m_action, m_reward, m_next_state, m_done in minibatch:
        if len(m_state) > 0:
            m_q_values = model.predict([[m_state[0],m_state[1],m_state[2],m_state[3]]])
            
            #How good is this action?
            if m_done :
                m_q_values[0][m_action] = m_reward
            else:  
                m_q_values[0][m_action] = m_reward + gamma * np.max(target_network.predict([[m_next_state[0],m_next_state[1], m_next_state[2], m_next_state[3]]])[0])

                
            #Add to the list of states
            state_batch.append([m_state[0],m_state[1],m_state[2],m_state[3]])
            
            #Add to the list of q values
            q_batch.append(m_q_values[0])
    
    # Train on the batch
    loss = model.train_on_batch(np.array(state_batch),np.array(q_batch))
    
    return loss


#Evaluate our model and, if it is better than the previous best, save the new weights
def update_scores():
    global max_reward
    round_reward = scores[len(scores)-1]
    if round_reward >= max_reward:
        model.save("./dqn_exp_replay_tgtnetwork.h5")
        max_reward = round_reward
    scores.append(round_reward)
    episode_reward_list.append(round_reward)


    
#Update the target network
def update_target():
    global steps_to_target
    # Update target network if it is time 
    if steps_to_target<=0:
        target_network.set_weights(model.get_weights())
        steps_to_target = target_update_steps
    # Otherwise count down
    else:
        steps_to_target-=1
    
    

    
#Deep q-learning algorithm using experience replay and a target network
def dql_with_experience_replay_target(state):
    global exploring_rate
    global epsilon
    global memory
    global done
    global reward
    
    # Update the exploring rate for the first round and 
    if done or len(scores) <= 0:
        update_exploring_rate(len(scores)+1)
        print(exploring_rate*100, "% random")
    
    # Update scores and target after each round
    if done:
        update_target()
        update_scores()
        loss = experience_replay()
    
    # Add each state change and its reward to memory for experience replay
    if len(last_state) >= 0:
        memory.append((last_state, a, reward, state, done))
    
    # Decide whether we should explore or exploit
    exploring =  np.random.choice([True,False], p=[exploring_rate,1-exploring_rate])
            
    
    if exploring: # Exploration
        action = env.action_space.sample() # Random action
    else: # Exploitation
        action = deep_q_policy(state) # Estimated best action
        
    
    return action
    


def run_cartPole_asAgent(policy=None):
    global last_state
    global a
    global reward
    global done
    
    env.reset()
    env.render()
    env.viewer.window.on_key_press = key_press

    for _ in range(number_of_trials):
        state = env.reset()
        total_reward = 0.0
        steps = 0
        restart = False
        t1 = time.time()  # Trial timer
        while bool_do_not_quit:
            #this is where policy function outputs action a based on the current state
            a = policy(state)
            last_state = copy.copy(state)
            #this is there you get the next system state after take action a
            state, reward, done, info = env.step(a)
            time.sleep(1/10)  # 10fps: Super slow for us poor little human!
            total_reward += reward
            steps += 1
            env.render()
            if done or restart:
                t1 = time.time()-t1
                scores.append(total_reward)
                print("Episode", len(scores), "| Score:", total_reward, '|', steps, "steps | %0.2fs."% t1)
                break
    env.close()


run_cartPole_asAgent(policy=dql_with_experience_replay_target)  # Run with agent input


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import statistics
print("Average Score for ", number_of_trials, " episodes is:",statistics.mean(scores))
# Plot your score
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.title('My agent performance on CartPole-v0')
plt.ylabel('Score')
plt.xlabel('Agent Episode')
plt.show()

# %%
#Set the best agent off playing

def play_best():
    model.load_weights("./best_dqn.h5")
    run_cartPole_asAgent(policy=deep_q_policy)

play_best()

# Plot your score
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.title('My agent performance on CartPole-v0')
plt.ylabel('Score')
plt.xlabel('Agent Episode')
plt.show()
