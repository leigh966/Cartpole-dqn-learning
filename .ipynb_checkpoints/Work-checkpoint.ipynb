# %%
# !pip install gymnasium
# !pip install pyglet
# !pip install pygame
# Out:
# Requirement already satisfied: gymnasium in c:\users\leigh\anaconda3\lib\site-packages (0.29.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (4.8.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\leigh\anaconda3\lib\site-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\leigh\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.6.0)
# Requirement already satisfied: pyglet in c:\users\leigh\anaconda3\lib\site-packages (2.0.9)
# Requirement already satisfied: pygame in c:\users\leigh\anaconda3\lib\site-packages (2.5.1)

# %%
#This is the mannual game play cell
import gymnasium as gym
from gym.envs.classic_control.cartpole import *
from pyglet.window import key
import matplotlib.pyplot as plt
import time
from gymnasium.utils.play import play

bool_do_not_quit = True  # Boolean to quit pyglet
scores = []  # Your gaming score
a = 0  # Action
total_reward = 0
episode = 1
steps = 0
start_time = time.time()

def cartpole_callback(obs, q_obs, action, reward, terminated, truncated, info):
    global total_reward, steps, start_time
    total_reward += reward
    steps += 1
    if terminated or truncated:
        print("Episode", len(scores), "| Score:", total_reward, '|', steps, "steps | %0.2fs."% (time.time()-start_time))
        scores.append(total_reward)
        total_reward = 0
        steps = 0
        start_time = time.time()
    
    
    
def run_cartPole_asHuman(policy=None):
    env = gym.make('CartPole-v1', render_mode="rgb_array")
    env.reset()
    play(env, keys_to_action={"a":0, "d":1}, callback=cartpole_callback, fps=10)



run_cartPole_asHuman() 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import statistics
print("Average Score for ", len(scores), " episodes is:",statistics.mean(scores))
# Plot your score
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.title('My human performance on CartPole-v1')
plt.ylabel('Score')
plt.xlabel('Human Episode')
plt.show()
# Out:
# Episode 0 | Score: 9.0 | 9 steps | 0.93s.
# Episode 1 | Score: 9.0 | 9 steps | 1.01s.
# Episode 2 | Score: 9.0 | 9 steps | 1.00s.
# Episode 3 | Score: 9.0 | 9 steps | 1.01s.
# Episode 4 | Score: 9.0 | 9 steps | 1.01s.
# Episode 5 | Score: 10.0 | 10 steps | 1.10s.
# Episode 6 | Score: 10.0 | 10 steps | 1.11s.
# Episode 7 | Score: 9.0 | 9 steps | 1.00s.
# Episode 8 | Score: 11.0 | 11 steps | 1.20s.
# Episode 9 | Score: 24.0 | 24 steps | 2.51s.
# Episode 10 | Score: 100.0 | 100 steps | 10.15s.
# Episode 11 | Score: 53.0 | 53 steps | 5.43s.
# Episode 12 | Score: 77.0 | 77 steps | 7.84s.
# Episode 13 | Score: 17.0 | 17 steps | 1.81s.
# Average Score for  14  episodes is: 25.428571428571427

# %%
import gym
from gym.envs.classic_control.cartpole import *
from pyglet.window import key
import matplotlib.pyplot as plt
import time


bool_do_not_quit = True  # Boolean to quit pyglet
scores = []  # Your gaming score
a = 0  # Action
#env = gym.make('CartPole-v1', render_mode="human") #display
env = gym.make('CartPole-v1') #headless

number_of_trials = 500

def dummy_policy(state=0):
    a = env.action_space.sample()
    return a



import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,BatchNormalization,Activation
from tensorflow.keras.callbacks import ModelCheckpoint
import datetime,os
import collections
import random
import copy

def build_model():
    inputs = keras.Input(shape=(4,))
    x = layers.Dense(32,activation='tanh')(inputs)
    x = layers.Dense(64,activation='tanh')(x)

    outputs = layers.Dense(2, activation="linear")(x)

    model = keras.Model(inputs=inputs, outputs=outputs, name="dqn_model")
    #lr stands for learning rate
    optimizer = keras.optimizers.Adam(lr=0.001)

    model.compile(
        optimizer =optimizer,loss='mse',
    )
    return model

model= build_model()
target_network = build_model()
gamma = 0.95

epsilon = 1.0/number_of_trials

episode_reward_list = []     
exploring_rate=0.0
target_score = 200

memory = collections.deque(maxlen=100000)
batch_size=32
max_reward = -10000
target_update_steps = 20


steps_to_target = 20
done=False

last_state = []
a = []
reward = 0
total_reward = 0.0



#Get the predictd best action by our network
def deep_q_policy(state):
    
    #print("state: ", state)
    # Get the model's reward estimations of each Q(s,a)
    #action_q_values = model.predict([[state[0],state[1],state[2],state[3]]])
    #x = tf.random.uniform((1,4)) # working random - REPLACE (DEBUG)
    x=None
    try:
        x = tf.constant([[state[0], state[1], state[2], state[3]]])
    except:
        x = tf.constant([state[0]])
    #print(x)
    action_q_values = model.predict(x)
    
    # If exploiting, choose the model's estimated best action 
    return np.argmax(action_q_values)



#Change our exploring rate so that later rounds are less random later on (because our network will hopefully be improving)
def update_exploring_rate(roundNumber):
    global exploring_rate
    exploring_rate = 1-roundNumber*epsilon 
    if exploring_rate<0:
        exploring_rate = 0.01


        
# Feed our network the batch of state changes and rewards
def experience_replay():
    global memory
    state_batch, q_batch = [], []
    # Get a batch of random state changes from memory to train our network
    minibatch = random.sample(memory, min(len(memory), batch_size))
    for m_state, m_action, m_reward, m_next_state, m_done in minibatch:
        if len(m_state) > 0:
            #print("m_state: ", m_state)
            #m_q_values = model.predict([[m_state[0],m_state[1],m_state[2],m_state[3]]])
            #x = tf.random.uniform((1,4)) # working random - REPLACE (DEBUG)
            x=None
            try:
                x = tf.constant([[m_state[0], m_state[1], m_state[2], m_state[3]]])
            except:
                x = tf.constant([m_state[0]])
            #print(x)
            m_q_values = model.predict(x)
            #How good is this action?
            if m_done :
                m_q_values[0][m_action] = m_reward
            else:
                #x = tf.constant([m_next_state])
                #q_x = tf.random.uniform((1,4)) # working random - REPLACE (DEBUG)
                q_x = tf.constant([[m_next_state[0],m_next_state[1], m_next_state[2], m_next_state[3]]])
                #m_q_values[0][m_action] = m_reward + gamma * np.max(target_network.predict([[m_next_state[0],m_next_state[1], m_next_state[2], m_next_state[3]]])[0])
                m_q_values[0][m_action] = m_reward + gamma * np.max(target_network.predict(q_x)[0])
                
            #Add to the list of states
            #state_batch.append([m_state[0],m_state[1],m_state[2],m_state[3]])
            state_batch.append(x[0])
            
            #Add to the list of q values
            q_batch.append(m_q_values[0])
    
    # Train on the batch
    loss = model.train_on_batch(np.array(state_batch),np.array(q_batch))
    
    return loss


#Evaluate our model and, if it is better than the previous best, save the new weights
def update_scores():
    global max_reward
    round_reward = scores[len(scores)-1]
    if round_reward >= max_reward:
        model.save("./dqn_exp_replay_tgtnetwork.h5")
        max_reward = round_reward
    scores.append(round_reward)
    episode_reward_list.append(round_reward)


    
#Update the target network
def update_target():
    global steps_to_target
    # Update target network if it is time 
    if steps_to_target<=0:
        target_network.set_weights(model.get_weights())
        steps_to_target = target_update_steps
    # Otherwise count down
    else:
        steps_to_target-=1
    
    

    
#Deep q-learning algorithm using experience replay and a target network
def dql_with_experience_replay_target(state):
    global exploring_rate
    global epsilon
    global memory
    global done
    global reward
    
    # Update the exploring rate for the first round and 
    if done or len(scores) <= 0:
        update_exploring_rate(len(scores)+1)
        #print(exploring_rate*100, "% random")
    
    # Update scores and target after each round
    if done:
        update_target()
        update_scores()
        loss = experience_replay()
    
    # Add each state change and its reward to memory for experience replay
    if len(last_state) >= 0:
        memory.append((last_state, a, reward, state, done))
    
    # Decide whether we should explore or exploit
    exploring =  np.random.choice([True,False], p=[exploring_rate,1-exploring_rate])
            
    
    if exploring: # Exploration
        action = env.action_space.sample() # Random action
    else: # Exploitation
        action = deep_q_policy(state) # Estimated best action
        
    
    return action
    


def run_cartPole_asAgent(policy=None):
    global last_state
    global a
    global reward
    global done
    
    env.reset()
    env.render()

    for _ in range(number_of_trials):
        state = env.reset()
        total_reward = 0.0
        steps = 0
        restart = False
        t1 = time.time()  # Trial timer
        while bool_do_not_quit:
            #this is where policy function outputs action a based on the current state
            a = policy(state)
            last_state = copy.copy(state)
            #this is there you get the next system state after take action a
            state, reward, done, truncated, info = env.step(a)
            #time.sleep(1/10)  # 10fps: Super slow for us poor little human!
            total_reward += reward
            steps += 1
            env.render()
            if done or restart or truncated:
                t1 = time.time()-t1
                scores.append(total_reward)
                print("Episode", len(scores), "| Score:", total_reward, '|', steps, "steps | %0.2fs."% t1)
                break
    env.close()


run_cartPole_asAgent(policy=dql_with_experience_replay_target)  # Run with agent input


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import statistics
print("Average Score for ", number_of_trials, " episodes is:",statistics.mean(scores))
# Plot your score
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.title('My agent performance on CartPole-v1')
plt.ylabel('Score')
plt.xlabel('Agent Episode')
plt.show()
# Out:
# C:\Users\leigh\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\leigh\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# C:\Users\leigh\anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# C:\Users\leigh\anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 1 | Score: 14.0 | 14 steps | 0.00s.
# Episode 3 | Score: 15.0 | 15 steps | 1.15s.
# Episode 5 | Score: 10.0 | 10 steps | 1.64s.
# Episode 7 | Score: 12.0 | 12 steps | 1.79s.
# Episode 9 | Score: 14.0 | 14 steps | 1.75s.
# Episode 11 | Score: 14.0 | 14 steps | 1.62s.
# Episode 13 | Score: 18.0 | 18 steps | 1.79s.
# Episode 15 | Score: 11.0 | 11 steps | 1.70s.
# Episode 17 | Score: 27.0 | 27 steps | 1.72s.
# Episode 19 | Score: 14.0 | 14 steps | 1.78s.
# Episode 21 | Score: 27.0 | 27 steps | 1.78s.
# Episode 23 | Score: 48.0 | 48 steps | 1.74s.
# Episode 25 | Score: 14.0 | 14 steps | 1.76s.
# Episode 27 | Score: 17.0 | 17 steps | 1.92s.
# Episode 29 | Score: 17.0 | 17 steps | 1.71s.
# Episode 31 | Score: 41.0 | 41 steps | 1.79s.
# Episode 33 | Score: 17.0 | 17 steps | 1.87s.
# Episode 35 | Score: 21.0 | 21 steps | 1.75s.
# Episode 37 | Score: 12.0 | 12 steps | 1.71s.
# Episode 39 | Score: 23.0 | 23 steps | 1.73s.
# Episode 41 | Score: 30.0 | 30 steps | 1.84s.
# Episode 43 | Score: 13.0 | 13 steps | 1.92s.
# Episode 45 | Score: 16.0 | 16 steps | 1.75s.
# Episode 47 | Score: 20.0 | 20 steps | 1.79s.
# Episode 49 | Score: 12.0 | 12 steps | 1.70s.
# Episode 51 | Score: 23.0 | 23 steps | 1.71s.
# Episode 53 | Score: 21.0 | 21 steps | 1.76s.
# Episode 55 | Score: 13.0 | 13 steps | 1.79s.
# Episode 57 | Score: 20.0 | 20 steps | 1.90s.
# Episode 59 | Score: 46.0 | 46 steps | 1.88s.
# Episode 61 | Score: 44.0 | 44 steps | 2.04s.
# Episode 63 | Score: 20.0 | 20 steps | 1.92s.
# Episode 65 | Score: 15.0 | 15 steps | 1.78s.
# Episode 67 | Score: 19.0 | 19 steps | 1.90s.
# Episode 69 | Score: 18.0 | 18 steps | 1.72s.
# Episode 71 | Score: 15.0 | 15 steps | 1.75s.
# Episode 73 | Score: 38.0 | 38 steps | 1.95s.
# Episode 75 | Score: 20.0 | 20 steps | 1.77s.
# Episode 77 | Score: 12.0 | 12 steps | 1.87s.
# Episode 79 | Score: 12.0 | 12 steps | 1.76s.
# Episode 81 | Score: 29.0 | 29 steps | 1.85s.
# Episode 83 | Score: 20.0 | 20 steps | 1.76s.
# Episode 85 | Score: 36.0 | 36 steps | 1.83s.
# Episode 87 | Score: 15.0 | 15 steps | 1.82s.
# Episode 89 | Score: 22.0 | 22 steps | 1.73s.
# Episode 91 | Score: 21.0 | 21 steps | 1.87s.
# Episode 93 | Score: 11.0 | 11 steps | 1.91s.
# Episode 95 | Score: 17.0 | 17 steps | 1.87s.
# Episode 97 | Score: 14.0 | 14 steps | 1.79s.
# Episode 99 | Score: 40.0 | 40 steps | 2.03s.
# Episode 101 | Score: 23.0 | 23 steps | 1.86s.
# Episode 103 | Score: 14.0 | 14 steps | 1.86s.
# Episode 105 | Score: 31.0 | 31 steps | 1.83s.
# Episode 107 | Score: 15.0 | 15 steps | 1.80s.
# Episode 109 | Score: 33.0 | 33 steps | 2.08s.
# Episode 111 | Score: 11.0 | 11 steps | 1.73s.
# Episode 113 | Score: 16.0 | 16 steps | 1.67s.
# Episode 115 | Score: 19.0 | 19 steps | 1.85s.
# Episode 117 | Score: 14.0 | 14 steps | 1.79s.
# Episode 119 | Score: 15.0 | 15 steps | 1.71s.
# Episode 121 | Score: 26.0 | 26 steps | 1.78s.
# Episode 123 | Score: 13.0 | 13 steps | 1.92s.
# Episode 125 | Score: 17.0 | 17 steps | 1.90s.
# Episode 127 | Score: 10.0 | 10 steps | 1.77s.
# Episode 129 | Score: 24.0 | 24 steps | 1.87s.
# Episode 131 | Score: 25.0 | 25 steps | 1.90s.
# Episode 133 | Score: 18.0 | 18 steps | 1.89s.
# Episode 135 | Score: 14.0 | 14 steps | 1.97s.
# Episode 137 | Score: 30.0 | 30 steps | 1.92s.
# Episode 139 | Score: 18.0 | 18 steps | 1.88s.
# Episode 141 | Score: 11.0 | 11 steps | 1.90s.
# Episode 143 | Score: 19.0 | 19 steps | 1.74s.
# Episode 145 | Score: 29.0 | 29 steps | 1.98s.
# Episode 147 | Score: 12.0 | 12 steps | 1.77s.
# Episode 149 | Score: 28.0 | 28 steps | 1.90s.
# Episode 151 | Score: 13.0 | 13 steps | 1.83s.
# Episode 153 | Score: 13.0 | 13 steps | 1.91s.
# Episode 155 | Score: 16.0 | 16 steps | 1.89s.
# Episode 157 | Score: 19.0 | 19 steps | 2.03s.
# Episode 159 | Score: 16.0 | 16 steps | 1.82s.
# Episode 161 | Score: 10.0 | 10 steps | 1.76s.
# Episode 163 | Score: 12.0 | 12 steps | 1.89s.
# Episode 165 | Score: 10.0 | 10 steps | 1.76s.
# Episode 167 | Score: 25.0 | 25 steps | 1.92s.
# Episode 169 | Score: 22.0 | 22 steps | 1.87s.
# Episode 171 | Score: 11.0 | 11 steps | 1.86s.
# Episode 173 | Score: 16.0 | 16 steps | 2.03s.
# Episode 175 | Score: 15.0 | 15 steps | 1.88s.
# Episode 177 | Score: 21.0 | 21 steps | 1.86s.
# Episode 179 | Score: 10.0 | 10 steps | 1.88s.
# Episode 181 | Score: 15.0 | 15 steps | 1.89s.
# Episode 183 | Score: 15.0 | 15 steps | 1.79s.
# Episode 185 | Score: 14.0 | 14 steps | 1.88s.
# Episode 187 | Score: 15.0 | 15 steps | 1.85s.
# Episode 189 | Score: 12.0 | 12 steps | 2.03s.
# Episode 191 | Score: 11.0 | 11 steps | 1.90s.
# Episode 193 | Score: 23.0 | 23 steps | 1.98s.
# Episode 195 | Score: 22.0 | 22 steps | 1.91s.
# Episode 197 | Score: 16.0 | 16 steps | 1.97s.
# Episode 199 | Score: 10.0 | 10 steps | 1.82s.
# Episode 201 | Score: 28.0 | 28 steps | 2.01s.
# Episode 203 | Score: 11.0 | 11 steps | 2.03s.
# Episode 205 | Score: 12.0 | 12 steps | 1.88s.
# Episode 207 | Score: 14.0 | 14 steps | 1.79s.
# Episode 209 | Score: 28.0 | 28 steps | 2.07s.
# Episode 211 | Score: 17.0 | 17 steps | 2.03s.
# Episode 213 | Score: 22.0 | 22 steps | 1.95s.
# Episode 215 | Score: 12.0 | 12 steps | 1.97s.
# Episode 217 | Score: 12.0 | 12 steps | 1.80s.
# Episode 219 | Score: 13.0 | 13 steps | 2.06s.
# Episode 221 | Score: 23.0 | 23 steps | 1.96s.
# Episode 223 | Score: 20.0 | 20 steps | 1.89s.
# Episode 225 | Score: 13.0 | 13 steps | 1.76s.
# Episode 227 | Score: 14.0 | 14 steps | 1.81s.
# Episode 229 | Score: 11.0 | 11 steps | 1.88s.
# Episode 231 | Score: 10.0 | 10 steps | 1.83s.
# Episode 233 | Score: 14.0 | 14 steps | 1.86s.
# Episode 235 | Score: 14.0 | 14 steps | 2.10s.
# Episode 237 | Score: 22.0 | 22 steps | 1.95s.
# Episode 239 | Score: 16.0 | 16 steps | 2.04s.
# Episode 241 | Score: 13.0 | 13 steps | 1.84s.
# Episode 243 | Score: 17.0 | 17 steps | 1.99s.
# Episode 245 | Score: 27.0 | 27 steps | 1.96s.
# Episode 247 | Score: 16.0 | 16 steps | 1.85s.
# Episode 249 | Score: 17.0 | 17 steps | 1.96s.
# Episode 251 | Score: 11.0 | 11 steps | 1.90s.
# Episode 253 | Score: 10.0 | 10 steps | 1.89s.
# Episode 255 | Score: 15.0 | 15 steps | 1.95s.
# Episode 257 | Score: 15.0 | 15 steps | 2.05s.
# Episode 259 | Score: 18.0 | 18 steps | 1.88s.
# Episode 261 | Score: 16.0 | 16 steps | 1.81s.
# Episode 263 | Score: 13.0 | 13 steps | 1.97s.
# Episode 265 | Score: 18.0 | 18 steps | 2.16s.
# Episode 267 | Score: 40.0 | 40 steps | 2.27s.
# Episode 269 | Score: 13.0 | 13 steps | 1.98s.
# Episode 271 | Score: 21.0 | 21 steps | 2.06s.
# Episode 273 | Score: 19.0 | 19 steps | 2.07s.
# Episode 275 | Score: 16.0 | 16 steps | 2.01s.
# Episode 277 | Score: 18.0 | 18 steps | 2.17s.
# Episode 279 | Score: 13.0 | 13 steps | 1.99s.
# Episode 281 | Score: 18.0 | 18 steps | 2.10s.
# Episode 283 | Score: 15.0 | 15 steps | 1.91s.
# Episode 285 | Score: 17.0 | 17 steps | 2.12s.
# Episode 287 | Score: 14.0 | 14 steps | 1.93s.
# Episode 289 | Score: 14.0 | 14 steps | 1.82s.
# Episode 291 | Score: 13.0 | 13 steps | 2.05s.
# Episode 293 | Score: 11.0 | 11 steps | 1.86s.
# Episode 295 | Score: 11.0 | 11 steps | 2.06s.
# Episode 297 | Score: 10.0 | 10 steps | 1.94s.
# Episode 299 | Score: 10.0 | 10 steps | 1.93s.
# Episode 301 | Score: 36.0 | 36 steps | 2.08s.
# Episode 303 | Score: 15.0 | 15 steps | 2.00s.
# Episode 305 | Score: 13.0 | 13 steps | 1.98s.
# Episode 307 | Score: 17.0 | 17 steps | 1.88s.
# Episode 309 | Score: 12.0 | 12 steps | 1.79s.
# Episode 311 | Score: 13.0 | 13 steps | 2.09s.
# Episode 313 | Score: 19.0 | 19 steps | 1.98s.
# Episode 315 | Score: 17.0 | 17 steps | 1.94s.
# Episode 317 | Score: 13.0 | 13 steps | 1.93s.
# Episode 319 | Score: 17.0 | 17 steps | 1.98s.
# Episode 321 | Score: 13.0 | 13 steps | 1.97s.
# Episode 323 | Score: 20.0 | 20 steps | 1.99s.
# Episode 325 | Score: 19.0 | 19 steps | 2.24s.
# Episode 327 | Score: 22.0 | 22 steps | 2.05s.
# Episode 329 | Score: 20.0 | 20 steps | 2.00s.
# Episode 331 | Score: 21.0 | 21 steps | 2.08s.
# Episode 333 | Score: 23.0 | 23 steps | 2.01s.
# Episode 335 | Score: 39.0 | 39 steps | 2.45s.
# Episode 337 | Score: 16.0 | 16 steps | 2.13s.
# Episode 339 | Score: 11.0 | 11 steps | 1.93s.
# Episode 341 | Score: 29.0 | 29 steps | 2.20s.
# Episode 343 | Score: 26.0 | 26 steps | 2.30s.
# Episode 345 | Score: 22.0 | 22 steps | 2.06s.
# Episode 347 | Score: 17.0 | 17 steps | 2.09s.
# Episode 349 | Score: 15.0 | 15 steps | 2.07s.
# Episode 351 | Score: 25.0 | 25 steps | 2.21s.
# Episode 353 | Score: 20.0 | 20 steps | 2.28s.
# Episode 355 | Score: 18.0 | 18 steps | 2.05s.
# Episode 357 | Score: 19.0 | 19 steps | 2.11s.
# Episode 359 | Score: 18.0 | 18 steps | 2.05s.
# Episode 361 | Score: 19.0 | 19 steps | 2.01s.
# Episode 363 | Score: 17.0 | 17 steps | 2.06s.
# Episode 365 | Score: 22.0 | 22 steps | 2.15s.
# Episode 367 | Score: 19.0 | 19 steps | 2.23s.
# Episode 369 | Score: 20.0 | 20 steps | 2.15s.
# Episode 371 | Score: 17.0 | 17 steps | 2.06s.
# Episode 373 | Score: 20.0 | 20 steps | 2.00s.
# Episode 375 | Score: 12.0 | 12 steps | 1.93s.
# Episode 377 | Score: 43.0 | 43 steps | 2.55s.
# Episode 379 | Score: 30.0 | 30 steps | 2.44s.
# Episode 381 | Score: 28.0 | 28 steps | 2.32s.
# Episode 383 | Score: 67.0 | 67 steps | 3.22s.
# Episode 385 | Score: 157.0 | 157 steps | 5.01s.
# Episode 387 | Score: 54.0 | 54 steps | 2.97s.
# Episode 389 | Score: 90.0 | 90 steps | 3.50s.
# Episode 391 | Score: 36.0 | 36 steps | 2.49s.
# Episode 393 | Score: 48.0 | 48 steps | 2.71s.
# Episode 395 | Score: 32.0 | 32 steps | 2.53s.
# Episode 397 | Score: 36.0 | 36 steps | 2.44s.
# Episode 399 | Score: 27.0 | 27 steps | 2.31s.
# Episode 401 | Score: 22.0 | 22 steps | 2.24s.
# Episode 403 | Score: 16.0 | 16 steps | 2.03s.
# Episode 405 | Score: 14.0 | 14 steps | 2.05s.
# Episode 407 | Score: 9.0 | 9 steps | 1.89s.
# Episode 409 | Score: 9.0 | 9 steps | 1.88s.
# Episode 411 | Score: 11.0 | 11 steps | 1.94s.
# Episode 413 | Score: 12.0 | 12 steps | 1.87s.
# Episode 415 | Score: 10.0 | 10 steps | 2.04s.
# Episode 417 | Score: 14.0 | 14 steps | 2.06s.
# Episode 419 | Score: 13.0 | 13 steps | 1.88s.
# Episode 421 | Score: 8.0 | 8 steps | 1.93s.
# Episode 423 | Score: 9.0 | 9 steps | 1.86s.
# Episode 425 | Score: 10.0 | 10 steps | 1.99s.
# Episode 427 | Score: 10.0 | 10 steps | 2.03s.
# Episode 429 | Score: 9.0 | 9 steps | 1.95s.
# Episode 431 | Score: 11.0 | 11 steps | 2.08s.
# Episode 433 | Score: 9.0 | 9 steps | 1.91s.
# Episode 435 | Score: 11.0 | 11 steps | 2.03s.
# Episode 437 | Score: 13.0 | 13 steps | 2.06s.
# Episode 439 | Score: 16.0 | 16 steps | 2.15s.
# Episode 441 | Score: 10.0 | 10 steps | 1.93s.
# Episode 443 | Score: 15.0 | 15 steps | 2.07s.
# Episode 445 | Score: 12.0 | 12 steps | 2.20s.
# Episode 447 | Score: 16.0 | 16 steps | 2.07s.
# Episode 449 | Score: 14.0 | 14 steps | 2.03s.
# Episode 451 | Score: 16.0 | 16 steps | 2.09s.
# Episode 453 | Score: 12.0 | 12 steps | 2.06s.
# Episode 455 | Score: 16.0 | 16 steps | 2.00s.
# Episode 457 | Score: 15.0 | 15 steps | 2.05s.
# Episode 459 | Score: 14.0 | 14 steps | 2.21s.
# Episode 461 | Score: 13.0 | 13 steps | 2.13s.
# Episode 463 | Score: 12.0 | 12 steps | 1.95s.
# Episode 465 | Score: 11.0 | 11 steps | 2.00s.
# Episode 467 | Score: 12.0 | 12 steps | 2.06s.
# Episode 469 | Score: 13.0 | 13 steps | 2.06s.
# Episode 471 | Score: 17.0 | 17 steps | 2.16s.
# Episode 473 | Score: 18.0 | 18 steps | 2.36s.
# Episode 475 | Score: 15.0 | 15 steps | 2.05s.
# Episode 477 | Score: 17.0 | 17 steps | 2.18s.
# Episode 479 | Score: 14.0 | 14 steps | 2.12s.
# Episode 481 | Score: 15.0 | 15 steps | 2.11s.
# Episode 483 | Score: 13.0 | 13 steps | 2.10s.
# Episode 485 | Score: 15.0 | 15 steps | 2.11s.
# Episode 487 | Score: 13.0 | 13 steps | 2.18s.
# Episode 489 | Score: 10.0 | 10 steps | 2.03s.
# Episode 491 | Score: 9.0 | 9 steps | 1.91s.
# Episode 493 | Score: 10.0 | 10 steps | 1.99s.
# Episode 495 | Score: 9.0 | 9 steps | 1.93s.
# Episode 497 | Score: 9.0 | 9 steps | 1.92s.
# Episode 499 | Score: 10.0 | 10 steps | 1.95s.
# Episode 501 | Score: 10.0 | 10 steps | 2.03s.
# Episode 503 | Score: 9.0 | 9 steps | 2.02s.
# Episode 505 | Score: 10.0 | 10 steps | 1.94s.
# Episode 507 | Score: 9.0 | 9 steps | 2.00s.
# Episode 509 | Score: 9.0 | 9 steps | 1.90s.
# Episode 511 | Score: 10.0 | 10 steps | 1.97s.
# Episode 513 | Score: 9.0 | 9 steps | 2.03s.
# Episode 515 | Score: 17.0 | 17 steps | 2.09s.
# Episode 517 | Score: 24.0 | 24 steps | 2.52s.
# Episode 519 | Score: 14.0 | 14 steps | 2.01s.
# Episode 521 | Score: 12.0 | 12 steps | 2.06s.
# Episode 523 | Score: 10.0 | 10 steps | 2.03s.
# Episode 525 | Score: 9.0 | 9 steps | 1.95s.
# Episode 527 | Score: 8.0 | 8 steps | 1.90s.
# Episode 529 | Score: 9.0 | 9 steps | 1.98s.
# Episode 531 | Score: 9.0 | 9 steps | 1.87s.
# Episode 533 | Score: 9.0 | 9 steps | 2.08s.
# Episode 535 | Score: 10.0 | 10 steps | 2.00s.
# Episode 537 | Score: 9.0 | 9 steps | 1.98s.
# Episode 539 | Score: 10.0 | 10 steps | 1.98s.
# Episode 541 | Score: 9.0 | 9 steps | 1.87s.
# Episode 543 | Score: 10.0 | 10 steps | 1.93s.
# Episode 545 | Score: 9.0 | 9 steps | 1.91s.
# Episode 547 | Score: 10.0 | 10 steps | 2.16s.
# Episode 549 | Score: 10.0 | 10 steps | 1.94s.
# Episode 551 | Score: 9.0 | 9 steps | 1.82s.
# Episode 553 | Score: 10.0 | 10 steps | 1.99s.
# Episode 555 | Score: 8.0 | 8 steps | 1.91s.
# Episode 557 | Score: 9.0 | 9 steps | 1.96s.
# Episode 559 | Score: 10.0 | 10 steps | 1.96s.
# Episode 561 | Score: 9.0 | 9 steps | 1.96s.
# Episode 563 | Score: 12.0 | 12 steps | 2.15s.
# Episode 565 | Score: 11.0 | 11 steps | 2.03s.
# Episode 567 | Score: 15.0 | 15 steps | 2.11s.
# Episode 569 | Score: 19.0 | 19 steps | 2.26s.
# Episode 571 | Score: 16.0 | 16 steps | 2.14s.
# Episode 573 | Score: 23.0 | 23 steps | 2.25s.
# Episode 575 | Score: 24.0 | 24 steps | 2.42s.
# Episode 577 | Score: 23.0 | 23 steps | 2.44s.
# Episode 579 | Score: 19.0 | 19 steps | 2.26s.
# Episode 581 | Score: 33.0 | 33 steps | 2.54s.
# Episode 583 | Score: 26.0 | 26 steps | 2.43s.
# Episode 585 | Score: 19.0 | 19 steps | 2.25s.
# Episode 587 | Score: 21.0 | 21 steps | 2.22s.
# Episode 589 | Score: 25.0 | 25 steps | 2.46s.
# Episode 591 | Score: 30.0 | 30 steps | 2.49s.
# Episode 593 | Score: 26.0 | 26 steps | 2.34s.
# Episode 595 | Score: 23.0 | 23 steps | 2.32s.
# Episode 597 | Score: 22.0 | 22 steps | 2.22s.
# Episode 599 | Score: 18.0 | 18 steps | 2.23s.
# Episode 601 | Score: 16.0 | 16 steps | 2.30s.
# Episode 603 | Score: 22.0 | 22 steps | 2.29s.
# Episode 605 | Score: 26.0 | 26 steps | 2.33s.
# Episode 607 | Score: 26.0 | 26 steps | 2.32s.
# Episode 609 | Score: 22.0 | 22 steps | 2.35s.
# Episode 611 | Score: 18.0 | 18 steps | 2.17s.
# Episode 613 | Score: 24.0 | 24 steps | 2.37s.
# Episode 615 | Score: 17.0 | 17 steps | 2.33s.
# Episode 617 | Score: 19.0 | 19 steps | 2.25s.
# Episode 619 | Score: 23.0 | 23 steps | 2.36s.
# Episode 621 | Score: 23.0 | 23 steps | 2.27s.
# Episode 623 | Score: 19.0 | 19 steps | 2.24s.
# Episode 625 | Score: 23.0 | 23 steps | 2.37s.
# Episode 627 | Score: 21.0 | 21 steps | 2.35s.
# Episode 629 | Score: 22.0 | 22 steps | 2.33s.
# Episode 631 | Score: 20.0 | 20 steps | 2.25s.
# Episode 633 | Score: 31.0 | 31 steps | 2.61s.
# Episode 635 | Score: 29.0 | 29 steps | 2.52s.
# Episode 637 | Score: 29.0 | 29 steps | 2.47s.
# Episode 639 | Score: 27.0 | 27 steps | 2.61s.
# Episode 641 | Score: 21.0 | 21 steps | 2.23s.
# Episode 643 | Score: 20.0 | 20 steps | 2.21s.
# Episode 645 | Score: 20.0 | 20 steps | 2.25s.
# Episode 647 | Score: 21.0 | 21 steps | 2.30s.
# Episode 649 | Score: 14.0 | 14 steps | 2.12s.
# Episode 651 | Score: 12.0 | 12 steps | 1.97s.
# Episode 653 | Score: 12.0 | 12 steps | 2.14s.
# Episode 655 | Score: 15.0 | 15 steps | 2.13s.
# Episode 657 | Score: 16.0 | 16 steps | 2.09s.
# Episode 659 | Score: 14.0 | 14 steps | 2.10s.
# Episode 661 | Score: 12.0 | 12 steps | 2.09s.
# Episode 663 | Score: 14.0 | 14 steps | 1.96s.
# Episode 665 | Score: 11.0 | 11 steps | 2.05s.
# Episode 667 | Score: 14.0 | 14 steps | 2.16s.
# Episode 669 | Score: 10.0 | 10 steps | 2.00s.
# Episode 671 | Score: 15.0 | 15 steps | 2.13s.
# Episode 673 | Score: 19.0 | 19 steps | 2.19s.
# Episode 675 | Score: 15.0 | 15 steps | 2.06s.
# Episode 677 | Score: 19.0 | 19 steps | 2.23s.
# Episode 679 | Score: 15.0 | 15 steps | 2.06s.
# Episode 681 | Score: 18.0 | 18 steps | 2.27s.
# Episode 683 | Score: 15.0 | 15 steps | 2.13s.
# Episode 685 | Score: 16.0 | 16 steps | 2.09s.
# Episode 687 | Score: 19.0 | 19 steps | 2.29s.
# Episode 689 | Score: 15.0 | 15 steps | 2.12s.
# Episode 691 | Score: 19.0 | 19 steps | 2.19s.
# Episode 693 | Score: 16.0 | 16 steps | 2.14s.
# Episode 695 | Score: 18.0 | 18 steps | 2.31s.
# Episode 697 | Score: 21.0 | 21 steps | 2.24s.
# Episode 699 | Score: 18.0 | 18 steps | 2.17s.
# Episode 701 | Score: 29.0 | 29 steps | 2.42s.
# Episode 703 | Score: 33.0 | 33 steps | 2.58s.
# Episode 705 | Score: 24.0 | 24 steps | 2.32s.
# Episode 707 | Score: 42.0 | 42 steps | 3.00s.
# Episode 709 | Score: 28.0 | 28 steps | 2.41s.
# Episode 711 | Score: 82.0 | 82 steps | 3.86s.
# Episode 713 | Score: 116.0 | 116 steps | 4.77s.
# Episode 715 | Score: 94.0 | 94 steps | 4.29s.
# Episode 717 | Score: 93.0 | 93 steps | 4.28s.
# Episode 719 | Score: 90.0 | 90 steps | 4.16s.
# Episode 721 | Score: 61.0 | 61 steps | 3.33s.
# Episode 723 | Score: 47.0 | 47 steps | 3.11s.
# Episode 725 | Score: 64.0 | 64 steps | 3.49s.
# Episode 727 | Score: 62.0 | 62 steps | 3.30s.
# Episode 729 | Score: 61.0 | 61 steps | 3.44s.
# Episode 731 | Score: 76.0 | 76 steps | 3.81s.
# Episode 733 | Score: 69.0 | 69 steps | 3.57s.
# Episode 735 | Score: 63.0 | 63 steps | 3.34s.
# Episode 737 | Score: 59.0 | 59 steps | 3.37s.
# Episode 739 | Score: 47.0 | 47 steps | 3.18s.
# Episode 741 | Score: 36.0 | 36 steps | 2.67s.
# Episode 743 | Score: 78.0 | 78 steps | 3.95s.
# Episode 745 | Score: 41.0 | 41 steps | 2.89s.
# Episode 747 | Score: 37.0 | 37 steps | 2.73s.
# Episode 749 | Score: 29.0 | 29 steps | 2.61s.
# Episode 751 | Score: 49.0 | 49 steps | 3.05s.
# Episode 753 | Score: 55.0 | 55 steps | 3.11s.
# Episode 755 | Score: 26.0 | 26 steps | 2.31s.
# Episode 757 | Score: 21.0 | 21 steps | 2.24s.
# Episode 759 | Score: 30.0 | 30 steps | 2.56s.
# Episode 761 | Score: 25.0 | 25 steps | 2.54s.
# Episode 763 | Score: 21.0 | 21 steps | 2.33s.
# Episode 765 | Score: 35.0 | 35 steps | 2.69s.
# Episode 767 | Score: 34.0 | 34 steps | 2.67s.
# Episode 769 | Score: 36.0 | 36 steps | 2.69s.
# Episode 771 | Score: 33.0 | 33 steps | 2.76s.
# Episode 773 | Score: 31.0 | 31 steps | 2.49s.
# Episode 775 | Score: 38.0 | 38 steps | 2.79s.
# Episode 777 | Score: 27.0 | 27 steps | 2.58s.
# Episode 779 | Score: 28.0 | 28 steps | 2.50s.
# Episode 781 | Score: 26.0 | 26 steps | 2.63s.
# Episode 783 | Score: 33.0 | 33 steps | 2.87s.
# Episode 785 | Score: 29.0 | 29 steps | 2.68s.
# Episode 787 | Score: 27.0 | 27 steps | 2.53s.
# Episode 789 | Score: 28.0 | 28 steps | 2.56s.
# Episode 791 | Score: 29.0 | 29 steps | 2.59s.
# Episode 793 | Score: 28.0 | 28 steps | 2.58s.
# Episode 795 | Score: 72.0 | 72 steps | 4.00s.
# Episode 797 | Score: 31.0 | 31 steps | 2.79s.
# Episode 799 | Score: 31.0 | 31 steps | 2.60s.
# Episode 801 | Score: 28.0 | 28 steps | 2.52s.
# Episode 803 | Score: 58.0 | 58 steps | 3.28s.
# Episode 805 | Score: 28.0 | 28 steps | 2.71s.
# Episode 807 | Score: 35.0 | 35 steps | 2.63s.
# Episode 809 | Score: 37.0 | 37 steps | 2.81s.
# Episode 811 | Score: 42.0 | 42 steps | 2.91s.
# Episode 813 | Score: 27.0 | 27 steps | 2.42s.
# Episode 815 | Score: 26.0 | 26 steps | 2.49s.
# Episode 817 | Score: 34.0 | 34 steps | 2.78s.
# Episode 819 | Score: 21.0 | 21 steps | 2.30s.
# Episode 821 | Score: 19.0 | 19 steps | 2.41s.
# Episode 823 | Score: 25.0 | 25 steps | 2.54s.
# Episode 825 | Score: 21.0 | 21 steps | 2.34s.
# Episode 827 | Score: 27.0 | 27 steps | 2.71s.
# Episode 829 | Score: 19.0 | 19 steps | 2.69s.
# Episode 831 | Score: 24.0 | 24 steps | 2.37s.
# Episode 833 | Score: 27.0 | 27 steps | 2.47s.
# Episode 835 | Score: 18.0 | 18 steps | 2.14s.
# Episode 837 | Score: 16.0 | 16 steps | 2.20s.
# Episode 839 | Score: 21.0 | 21 steps | 2.30s.
# Episode 841 | Score: 21.0 | 21 steps | 2.33s.
# Episode 843 | Score: 17.0 | 17 steps | 2.32s.
# Episode 845 | Score: 19.0 | 19 steps | 2.27s.
# Episode 847 | Score: 19.0 | 19 steps | 2.18s.
# Episode 849 | Score: 18.0 | 18 steps | 2.22s.
# Episode 851 | Score: 19.0 | 19 steps | 2.11s.
# Episode 853 | Score: 27.0 | 27 steps | 2.53s.
# Episode 855 | Score: 18.0 | 18 steps | 2.39s.
# Episode 857 | Score: 24.0 | 24 steps | 2.32s.
# Episode 859 | Score: 24.0 | 24 steps | 2.37s.
# Episode 861 | Score: 25.0 | 25 steps | 2.39s.
# Episode 863 | Score: 21.0 | 21 steps | 2.39s.
# Episode 865 | Score: 18.0 | 18 steps | 2.23s.
# Episode 867 | Score: 22.0 | 22 steps | 2.44s.
# Episode 869 | Score: 24.0 | 24 steps | 2.36s.
# Episode 871 | Score: 29.0 | 29 steps | 2.54s.
# Episode 873 | Score: 28.0 | 28 steps | 2.52s.
# Episode 875 | Score: 35.0 | 35 steps | 2.74s.
# Episode 877 | Score: 63.0 | 63 steps | 3.50s.
# Episode 879 | Score: 78.0 | 78 steps | 3.99s.
# Episode 881 | Score: 109.0 | 109 steps | 4.61s.
# Episode 883 | Score: 74.0 | 74 steps | 3.80s.
# Episode 885 | Score: 83.0 | 83 steps | 4.15s.
# Episode 887 | Score: 128.0 | 128 steps | 5.10s.
# Episode 889 | Score: 64.0 | 64 steps | 3.37s.
# Episode 891 | Score: 35.0 | 35 steps | 2.66s.
# Episode 893 | Score: 42.0 | 42 steps | 2.83s.
# Episode 895 | Score: 28.0 | 28 steps | 2.53s.
# Episode 897 | Score: 39.0 | 39 steps | 2.71s.
# Episode 899 | Score: 33.0 | 33 steps | 2.61s.
# Episode 901 | Score: 34.0 | 34 steps | 2.75s.
# Episode 903 | Score: 36.0 | 36 steps | 2.75s.
# Episode 905 | Score: 36.0 | 36 steps | 2.92s.
# Episode 907 | Score: 34.0 | 34 steps | 2.64s.
# Episode 909 | Score: 49.0 | 49 steps | 3.05s.
# Episode 911 | Score: 37.0 | 37 steps | 2.73s.
# Episode 913 | Score: 50.0 | 50 steps | 3.15s.
# Episode 915 | Score: 79.0 | 79 steps | 4.16s.
# Episode 917 | Score: 118.0 | 118 steps | 5.10s.
# Episode 919 | Score: 82.0 | 82 steps | 4.00s.
# Episode 921 | Score: 213.0 | 213 steps | 7.84s.
# Episode 923 | Score: 70.0 | 70 steps | 3.65s.
# Episode 925 | Score: 167.0 | 167 steps | 6.35s.
# Episode 927 | Score: 125.0 | 125 steps | 5.36s.
# Episode 929 | Score: 41.0 | 41 steps | 2.95s.
# Episode 931 | Score: 45.0 | 45 steps | 2.91s.
# Episode 933 | Score: 57.0 | 57 steps | 3.50s.
# Episode 935 | Score: 32.0 | 32 steps | 2.65s.
# Episode 937 | Score: 31.0 | 31 steps | 2.81s.
# Episode 939 | Score: 27.0 | 27 steps | 2.43s.
# Episode 941 | Score: 30.0 | 30 steps | 2.60s.
# Episode 943 | Score: 32.0 | 32 steps | 2.61s.
# Episode 945 | Score: 41.0 | 41 steps | 2.94s.
# Episode 947 | Score: 76.0 | 76 steps | 3.99s.
# Episode 949 | Score: 58.0 | 58 steps | 3.48s.
# Episode 951 | Score: 51.0 | 51 steps | 3.22s.
# Episode 953 | Score: 37.0 | 37 steps | 2.73s.
# Episode 955 | Score: 53.0 | 53 steps | 3.27s.
# Episode 957 | Score: 50.0 | 50 steps | 3.29s.
# Episode 959 | Score: 59.0 | 59 steps | 3.37s.
# Episode 961 | Score: 63.0 | 63 steps | 3.57s.
# Episode 963 | Score: 73.0 | 73 steps | 4.02s.
# Episode 965 | Score: 76.0 | 76 steps | 4.17s.
# Episode 967 | Score: 100.0 | 100 steps | 4.58s.
# Episode 969 | Score: 192.0 | 192 steps | 7.20s.
# Episode 971 | Score: 108.0 | 108 steps | 4.98s.
# Episode 973 | Score: 155.0 | 155 steps | 6.06s.
# Episode 975 | Score: 55.0 | 55 steps | 3.31s.
# Episode 977 | Score: 67.0 | 67 steps | 3.94s.
# Episode 979 | Score: 87.0 | 87 steps | 4.20s.
# Episode 981 | Score: 100.0 | 100 steps | 4.48s.
# Episode 983 | Score: 66.0 | 66 steps | 3.67s.
# Episode 985 | Score: 108.0 | 108 steps | 4.97s.
# Episode 987 | Score: 331.0 | 331 steps | 11.33s.
# Episode 989 | Score: 88.0 | 88 steps | 4.41s.
# Episode 991 | Score: 46.0 | 46 steps | 3.13s.
# Episode 993 | Score: 68.0 | 68 steps | 3.68s.
# Episode 995 | Score: 51.0 | 51 steps | 3.20s.
# Episode 997 | Score: 30.0 | 30 steps | 2.95s.
# Episode 999 | Score: 28.0 | 28 steps | 2.61s.
# Average Score for  500  episodes is: 28.296296296296298

# %%
#Set the best agent off playing

def play_best():
    model.load_weights("./best_dqn.h5")
    run_cartPole_asAgent(policy=deep_q_policy)

play_best()

# Plot your score
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.title('My agent performance on CartPole-v0')
plt.ylabel('Score')
plt.xlabel('Agent Episode')
plt.show()
# Out:
# C:\Users\leigh\anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Episode 1000 | Score: 289.0 | 289 steps | 8.20s.
# Episode 1001 | Score: 500.0 | 500 steps | 14.20s.
# Episode 1002 | Score: 428.0 | 428 steps | 12.45s.
# Episode 1003 | Score: 500.0 | 500 steps | 13.96s.
# Episode 1004 | Score: 428.0 | 428 steps | 11.90s.
# Episode 1005 | Score: 450.0 | 450 steps | 12.51s.
# Episode 1006 | Score: 468.0 | 468 steps | 12.91s.
# Episode 1007 | Score: 384.0 | 384 steps | 10.68s.
# Episode 1008 | Score: 289.0 | 289 steps | 8.28s.
# Episode 1009 | Score: 500.0 | 500 steps | 14.22s.
# Episode 1010 | Score: 295.0 | 295 steps | 8.25s.
# Episode 1011 | Score: 244.0 | 244 steps | 6.84s.
# Episode 1012 | Score: 500.0 | 500 steps | 14.16s.
# Episode 1013 | Score: 500.0 | 500 steps | 14.38s.
# Episode 1014 | Score: 500.0 | 500 steps | 14.21s.
# Episode 1015 | Score: 284.0 | 284 steps | 8.23s.
# Episode 1016 | Score: 453.0 | 453 steps | 12.86s.
# Episode 1017 | Score: 500.0 | 500 steps | 14.09s.
# Episode 1018 | Score: 281.0 | 281 steps | 7.67s.
# Episode 1019 | Score: 500.0 | 500 steps | 14.34s.
# Episode 1020 | Score: 298.0 | 298 steps | 8.52s.
# Episode 1021 | Score: 251.0 | 251 steps | 6.85s.
# Episode 1022 | Score: 500.0 | 500 steps | 13.71s.
# Episode 1023 | Score: 484.0 | 484 steps | 13.31s.
# Episode 1024 | Score: 441.0 | 441 steps | 12.06s.
# Episode 1025 | Score: 500.0 | 500 steps | 13.90s.
# Episode 1026 | Score: 274.0 | 274 steps | 7.51s.
# Episode 1027 | Score: 289.0 | 289 steps | 8.08s.
# Episode 1028 | Score: 500.0 | 500 steps | 13.50s.
# Episode 1029 | Score: 500.0 | 500 steps | 13.94s.
# Episode 1030 | Score: 500.0 | 500 steps | 14.30s.
# Episode 1031 | Score: 500.0 | 500 steps | 14.07s.
# Episode 1032 | Score: 500.0 | 500 steps | 14.28s.
# Episode 1033 | Score: 500.0 | 500 steps | 14.03s.
# Episode 1034 | Score: 459.0 | 459 steps | 13.09s.
# Episode 1035 | Score: 500.0 | 500 steps | 14.11s.
# Episode 1036 | Score: 297.0 | 297 steps | 8.33s.
# Episode 1037 | Score: 500.0 | 500 steps | 13.71s.
# Episode 1038 | Score: 297.0 | 297 steps | 8.22s.
# Episode 1039 | Score: 376.0 | 376 steps | 10.37s.
# Episode 1040 | Score: 500.0 | 500 steps | 13.63s.
# Episode 1041 | Score: 500.0 | 500 steps | 13.78s.
# Episode 1042 | Score: 435.0 | 435 steps | 12.06s.
# Episode 1043 | Score: 243.0 | 243 steps | 6.78s.
# Episode 1044 | Score: 500.0 | 500 steps | 13.68s.
# Episode 1045 | Score: 500.0 | 500 steps | 13.65s.
# Episode 1046 | Score: 489.0 | 489 steps | 13.64s.
# Episode 1047 | Score: 500.0 | 500 steps | 14.07s.
# Episode 1048 | Score: 500.0 | 500 steps | 14.18s.
# Episode 1049 | Score: 407.0 | 407 steps | 11.50s.
# Episode 1050 | Score: 292.0 | 292 steps | 8.18s.
# Episode 1051 | Score: 299.0 | 299 steps | 8.72s.
# Episode 1052 | Score: 500.0 | 500 steps | 14.07s.
# Episode 1053 | Score: 500.0 | 500 steps | 14.02s.
# Episode 1054 | Score: 500.0 | 500 steps | 13.75s.
# Episode 1055 | Score: 500.0 | 500 steps | 13.89s.
# Episode 1056 | Score: 259.0 | 259 steps | 7.29s.
# Episode 1057 | Score: 500.0 | 500 steps | 14.11s.
# Episode 1058 | Score: 275.0 | 275 steps | 7.68s.
# Episode 1059 | Score: 436.0 | 436 steps | 11.89s.
# Episode 1060 | Score: 323.0 | 323 steps | 8.95s.
# Episode 1061 | Score: 450.0 | 450 steps | 12.54s.
# Episode 1062 | Score: 500.0 | 500 steps | 13.92s.
# Episode 1063 | Score: 347.0 | 347 steps | 9.50s.
# Episode 1064 | Score: 442.0 | 442 steps | 12.24s.
# Episode 1065 | Score: 450.0 | 450 steps | 12.45s.
# Episode 1066 | Score: 500.0 | 500 steps | 13.81s.
# Episode 1067 | Score: 286.0 | 286 steps | 7.83s.
# Episode 1068 | Score: 292.0 | 292 steps | 8.14s.
# Episode 1069 | Score: 478.0 | 478 steps | 13.20s.
# Episode 1070 | Score: 477.0 | 477 steps | 13.15s.
# Episode 1071 | Score: 500.0 | 500 steps | 13.83s.
# Episode 1072 | Score: 409.0 | 409 steps | 11.28s.
# Episode 1073 | Score: 384.0 | 384 steps | 10.72s.
# Episode 1074 | Score: 424.0 | 424 steps | 11.76s.
# Episode 1075 | Score: 500.0 | 500 steps | 13.93s.
# Episode 1076 | Score: 299.0 | 299 steps | 8.18s.
# Episode 1077 | Score: 422.0 | 422 steps | 11.74s.
# Episode 1078 | Score: 288.0 | 288 steps | 8.16s.
# Episode 1079 | Score: 500.0 | 500 steps | 13.87s.
# Episode 1080 | Score: 500.0 | 500 steps | 13.60s.
# Episode 1081 | Score: 500.0 | 500 steps | 13.89s.
# Episode 1082 | Score: 363.0 | 363 steps | 10.24s.
# Episode 1083 | Score: 500.0 | 500 steps | 13.89s.
# Episode 1084 | Score: 289.0 | 289 steps | 7.99s.
# Episode 1085 | Score: 404.0 | 404 steps | 11.11s.
# Episode 1086 | Score: 500.0 | 500 steps | 13.90s.
# Episode 1087 | Score: 269.0 | 269 steps | 7.53s.
# Episode 1088 | Score: 468.0 | 468 steps | 12.94s.
# Episode 1089 | Score: 500.0 | 500 steps | 13.94s.
# Episode 1090 | Score: 500.0 | 500 steps | 13.86s.
# Episode 1091 | Score: 500.0 | 500 steps | 13.97s.
# Episode 1092 | Score: 450.0 | 450 steps | 12.68s.
# Episode 1093 | Score: 500.0 | 500 steps | 14.09s.
# Episode 1094 | Score: 500.0 | 500 steps | 13.93s.
# Episode 1095 | Score: 500.0 | 500 steps | 14.08s.
# Episode 1096 | Score: 500.0 | 500 steps | 14.03s.
# Episode 1097 | Score: 500.0 | 500 steps | 13.98s.
# Episode 1098 | Score: 445.0 | 445 steps | 12.61s.
# Episode 1099 | Score: 488.0 | 488 steps | 13.48s.
# Episode 1100 | Score: 295.0 | 295 steps | 8.21s.
# Episode 1101 | Score: 388.0 | 388 steps | 11.06s.
# Episode 1102 | Score: 500.0 | 500 steps | 14.00s.
# Episode 1103 | Score: 500.0 | 500 steps | 13.81s.
# Episode 1104 | Score: 380.0 | 380 steps | 10.54s.
# Episode 1105 | Score: 419.0 | 419 steps | 11.66s.
# Episode 1106 | Score: 430.0 | 430 steps | 12.24s.
# Episode 1107 | Score: 408.0 | 408 steps | 11.52s.
# Episode 1108 | Score: 429.0 | 429 steps | 12.23s.
# Episode 1109 | Score: 299.0 | 299 steps | 8.55s.
# Episode 1110 | Score: 500.0 | 500 steps | 13.79s.
# Episode 1111 | Score: 494.0 | 494 steps | 13.75s.
# Episode 1112 | Score: 500.0 | 500 steps | 13.90s.
# Episode 1113 | Score: 500.0 | 500 steps | 13.93s.
# Episode 1114 | Score: 297.0 | 297 steps | 8.55s.
# Episode 1115 | Score: 481.0 | 481 steps | 13.25s.
# Episode 1116 | Score: 361.0 | 361 steps | 10.05s.
# Episode 1117 | Score: 500.0 | 500 steps | 13.84s.
# Episode 1118 | Score: 500.0 | 500 steps | 13.72s.
# Episode 1119 | Score: 290.0 | 290 steps | 8.06s.
# Episode 1120 | Score: 320.0 | 320 steps | 9.04s.
# Episode 1121 | Score: 477.0 | 477 steps | 13.10s.
# Episode 1122 | Score: 240.0 | 240 steps | 6.75s.
# Episode 1123 | Score: 500.0 | 500 steps | 13.93s.
# Episode 1124 | Score: 455.0 | 455 steps | 13.01s.
# Episode 1125 | Score: 407.0 | 407 steps | 11.17s.
# Episode 1126 | Score: 278.0 | 278 steps | 7.93s.
# Episode 1127 | Score: 430.0 | 430 steps | 11.90s.
# Episode 1128 | Score: 500.0 | 500 steps | 13.98s.
# Episode 1129 | Score: 500.0 | 500 steps | 13.85s.
# Episode 1130 | Score: 299.0 | 299 steps | 8.60s.
# Episode 1131 | Score: 500.0 | 500 steps | 14.41s.
# Episode 1132 | Score: 455.0 | 455 steps | 13.02s.
# Episode 1133 | Score: 431.0 | 431 steps | 12.50s.
# Episode 1134 | Score: 500.0 | 500 steps | 14.13s.
# Episode 1135 | Score: 405.0 | 405 steps | 11.21s.
# Episode 1136 | Score: 260.0 | 260 steps | 7.21s.
# Episode 1137 | Score: 500.0 | 500 steps | 13.91s.
# Episode 1138 | Score: 259.0 | 259 steps | 7.09s.
# Episode 1139 | Score: 500.0 | 500 steps | 13.77s.
# Episode 1140 | Score: 343.0 | 343 steps | 9.55s.
# Episode 1141 | Score: 500.0 | 500 steps | 13.73s.
# Episode 1142 | Score: 412.0 | 412 steps | 11.22s.
# Episode 1143 | Score: 500.0 | 500 steps | 13.77s.
# Episode 1144 | Score: 288.0 | 288 steps | 7.97s.
# Episode 1145 | Score: 302.0 | 302 steps | 8.22s.
# Episode 1146 | Score: 395.0 | 395 steps | 10.87s.
# Episode 1147 | Score: 440.0 | 440 steps | 12.20s.
# Episode 1148 | Score: 500.0 | 500 steps | 13.96s.
# Episode 1149 | Score: 500.0 | 500 steps | 13.81s.
# Episode 1150 | Score: 255.0 | 255 steps | 7.09s.
# Episode 1151 | Score: 500.0 | 500 steps | 13.94s.
# Episode 1152 | Score: 493.0 | 493 steps | 13.65s.
# Episode 1153 | Score: 500.0 | 500 steps | 14.00s.
# Episode 1154 | Score: 500.0 | 500 steps | 14.06s.
# Episode 1155 | Score: 264.0 | 264 steps | 7.37s.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21660/2519574184.py in <module>
#       5     run_cartPole_asAgent(policy=deep_q_policy)
#       6
# ----> 7 play_best()
#       8
#       9 # Plot your score
#
# ~\AppData\Local\Temp/ipykernel_21660/2519574184.py in play_best()
#       3 def play_best():
#       4     model.load_weights("./best_dqn.h5")
# ----> 5     run_cartPole_asAgent(policy=deep_q_policy)
#       6
#       7 play_best()
#
# ~\AppData\Local\Temp/ipykernel_21660/3827897401.py in run_cartPole_asAgent(policy)
#     223         while bool_do_not_quit:
#     224             #this is where policy function outputs action a based on the current state
# --> 225             a = policy(state)
#     226             last_state = copy.copy(state)
#     227             #this is there you get the next system state after take action a
#
# ~\AppData\Local\Temp/ipykernel_21660/3827897401.py in deep_q_policy(state)
#      86         x = tf.constant([state[0]])
#      87     #print(x)
# ---> 88     action_q_values = model.predict(x)
#      89
#      90     # If exploiting, choose the model's estimated best action
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1787           for step in data_handler.steps():
#    1788             callbacks.on_predict_batch_begin(step)
# -> 1789             tmp_batch_outputs = self.predict_function(iterator)
#    1790             if data_handler.should_sync:
#    1791               context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
